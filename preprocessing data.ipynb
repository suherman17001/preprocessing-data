# %%
#data preprocessing
#see the number of rows and columns, column headings
import pandas as pd
df = pd.read_csv("data")
print(df.shape)
print(dataset.head(10
#summary 
import pandas as pd
df = pd.read_csv("data")
print(df.describe())
#early identification of data distribution
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("data")
df[["data"]].plot.hist(figsize=(4, 5), bins=1, xlabelsize=8, ylabelsize=8)
plt.show()  # histogram plot

#outlier detecting
import pandas as pd
df = pd.read_csv("data")
# calculate quartile 1
Q1 = df[["data"]].quantile(0.25)
# calculate quartile 3
Q3 = df[["data"]].quantile(0.75)
# calculate inter quartile range 
IQR = Q3-Q1
print(IQR)
print((data < (Q1 - 1.5*IQR))|(data < (Q1 - 1.5*IQR)))
#normalize data
data_normalized = preprocessing.normalize(data, norm  = 'l1')
print "\nL1 normalized data = ", data_normalized
                
#missing value checking
# importing pandas as pd
import pandas as pd
# importing numpy as np
import numpy as np
# creating a dataframe from list
df = pd.DataFrame(data)
# using isnull() function  
df.isnull()
# creating bool series True for NaN values 
bool_series = pd.isnull(data["specific collumns"]) 
# filtering data 
# displaying data only with specific collumns = NaN 
data[bool_series]               
# using notnull() function 
df.notnull()
# creating bool series True for NaN values 
bool_series = pd.notnull(data["specific collumns"])   
# filtering data 
# displayind data only with specific collumns = Not NaN 
data[bool_series]                 
# creating a dataframe from dictionary
df = pd.DataFrame(dict)
# filling missing value using fillna()  
df.fillna(0)
# making data frame from csv file 
data = pd.read_csv("data")   
# filling a null values using fillna() 
data["specific collumns"].fillna("No Gender", inplace = True) # importing pandas package 
# will replace  Nan value in dataframe with value -99  
data.replace(to_replace = np.nan, value = -99) 
# using dropna() function  
df.dropna()
